# %%
import joblib
import os

# učitaj postojeće artefakte
best_model = joblib.load("best_model.pkl")
preprocessor = joblib.load("preprocessor.pkl")

# spremi "final" kopije (čisto radi reda)
joblib.dump(best_model, "final_model.pkl")
joblib.dump(preprocessor, "final_preprocessor.pkl")

print("Saved files:")
print([f for f in os.listdir(".") if f.endswith(".pkl")])
# Out:
# Saved files:
# ['best_model.pkl', 'final_model.pkl', 'final_preprocessor.pkl', 'preprocessor.pkl']
